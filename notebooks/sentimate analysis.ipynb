# %%
import nltk
from nltk.corpus import movie_reviews
from random import shuffle

documents = [(list(movie_reviews.words(fileid)), category) for category in movie_reviews.categories()for fileid in movie_reviews.fileids(category)]

shuffle(documents)

#documents[0]
# Out:
# ([u'robin',
#   u'hood',
#   u':',
#   u'men',
#   u'in',
#   u'tights',
#   u'is',
#   u'another',
#   u'mel',
#   u'-',
#   u'brooks',
#   u'-',
#   u'produced',
#   u'film',
#   u'in',
#   u'the',
#   u'classic',
#   u'tradition',
#   u'of',
#   u'movies',
#   u'like',
#   u'blazing',
#   u'saddles',
#   u'and',
#   u'young',
#   u'frankenstein',
#   u'.',
#   u'mel',
#   u'brooks',
#   u'is',
#   u'well',
#   u'known',
#   u'for',
#   u'his',
#   u'comic',
#   u'look',
#   u'at',
#   u'regular',
#   u'life',
#   u',',
#   u'his',
#   u'fast',
#   u'paced',
#   u'dialogue',
#   u'and',
#   u'sharp',
#   u'wit',
#   u'.',
#   u'unfortunately',
#   u',',
#   u'robin',
#   u'hood',
#   u':',
#   u'men',
#   u'in',
#   u'tights',
#   u'has',
#   u'none',
#   u'of',
#   u'the',
#   u'easy',
#   u'going',
#   u'humor',
#   u'of',
#   u'blazing',
#   u'saddles',
#   u',',
#   u'none',
#   u'of',
#   u'the',
#   u'fun',
#   u'acting',
#   u'of',
#   u'young',
#   u'frankenstein',
#   u',',
#   u'is',
#   u'devoid',
#   u'of',
#   u'the',
#   u'charm',
#   u'of',
#   u'spaceballs',
#   u',',
#   u'and',
#   u'is',
#   u'even',
#   u'lacking',
#   u'the',
#   u'good',
#   u',',
#   u'solid',
#   u'dialogue',
#   u'of',
#   u'history',
#   u'of',
#   u'the',
#   u'world',
#   u'.',
#   u'it',
#   u'is',
#   u',',
#   u'in',
#   u'short',
#   u',',
#   u'one',
#   u'of',
#   u'the',
#   u'worst',
#   u'movies',
#   u'i',
#   u'have',
#   u'seen',
#   u'mel',
#   u'brooks',
#   u',',
#   u'or',
#   u'anybody',
#   u'else',
#   u',',
#   u'produce',
#   u'.',
#   u'the',
#   u'plot',
#   u'borrows',
#   u'heavily',
#   u'from',
#   u'the',
#   u'well',
#   u'-',
#   u'received',
#   u'kevin',
#   u'costner',
#   u'movie',
#   u'of',
#   u'last',
#   u'year',
#   u',',
#   u'robin',
#   u'hood',
#   u':',
#   u'prince',
#   u'of',
#   u'thieves',
#   u'.',
#   u'this',
#   u'is',
#   u'not',
#   u'surprising',
#   u'in',
#   u'and',
#   u'of',
#   u'itself',
#   u',',
#   u'and',
#   u'could',
#   u'have',
#   u'been',
#   u'used',
#   u'to',
#   u'great',
#   u'comic',
#   u'effect',
#   u',',
#   u'mainly',
#   u'by',
#   u'parodying',
#   u'scenes',
#   u'from',
#   u'the',
#   u'orginal',
#   u'movie',
#   u'.',
#   u'mel',
#   u'brooks',
#   u'does',
#   u'not',
#   u'take',
#   u'advantage',
#   u'of',
#   u'this',
#   u',',
#   u'however',
#   u',',
#   u'and',
#   u'uses',
#   u'the',
#   u'film',
#   u'to',
#   u'launch',
#   u'several',
#   u'ideas',
#   u'into',
#   u'the',
#   u'air',
#   u',',
#   u'none',
#   u'of',
#   u'which',
#   u'connect',
#   u'and',
#   u'none',
#   u'of',
#   u'which',
#   u'are',
#   u'explained',
#   u'later',
#   u'on',
#   u'.',
#   u'the',
#   u'movie',
#   u"'",
#   u's',
#   u'scenes',
#   u'could',
#   u'be',
#   u'shuffled',
#   u'around',
#   u'in',
#   u'any',
#   u'order',
#   u'and',
#   u'one',
#   u'would',
#   u'be',
#   u'hard',
#   u'pressed',
#   u'to',
#   u'notice',
#   u'.',
#   u'cary',
#   u'elwes',
#   u',',
#   u'of',
#   u'princess',
#   u'bride',
#   u'fame',
#   u',',
#   u'plays',
#   u'robin',
#   u'of',
#   u'loxley',
#   u',',
#   u'a',
#   u'man',
#   u'who',
#   u'was',
#   u'captured',
#   u'in',
#   u'the',
#   u'crusades',
#   u',',
#   u'fighting',
#   u'with',
#   u'king',
#   u'richard',
#   u'.',
#   u'he',
#   u'escapes',
#   u'and',
#   u',',
#   u'joining',
#   u'with',
#   u'a',
#   u'man',
#   u'named',
#   u'achoo',
#   u'(',
#   u'i',
#   u'am',
#   u'sure',
#   u'you',
#   u'can',
#   u'see',
#   u'the',
#   u'obvious',
#   u'joke',
#   u')',
#   u',',
#   u'fights',
#   u'in',
#   u'england',
#   u'to',
#   u'reclaim',
#   u'his',
#   u'name',
#   u'and',
#   u'the',
#   u'throne',
#   u'for',
#   u'richard',
#   u',',
#   u'which',
#   u'has',
#   u'been',
#   u'captured',
#   u'by',
#   u'evil',
#   u'prince',
#   u'john',
#   u',',
#   u'played',
#   u'by',
#   u'funny',
#   u'comic',
#   u'richard',
#   u'lewis',
#   u'.',
#   u'he',
#   u'also',
#   u'tries',
#   u'for',
#   u'the',
#   u'love',
#   u'of',
#   u'maid',
#   u'marian',
#   u'and',
#   u'attempts',
#   u'to',
#   u'overthrow',
#   u'the',
#   u'evil',
#   u'"',
#   u'sheriff',
#   u'of',
#   u'rottingham',
#   u'"',
#   u'.',
#   u'a',
#   u'good',
#   u'adventure',
#   u'plot',
#   u'that',
#   u'is',
#   u'sadly',
#   u'unused',
#   u'.',
#   u'elwes',
#   u'and',
#   u'lewis',
#   u'are',
#   u'both',
#   u'excellent',
#   u'comics',
#   u',',
#   u'but',
#   u'the',
#   u'dialogue',
#   u'in',
#   u'the',
#   u'movie',
#   u'is',
#   u'simply',
#   u'excruciating',
#   u'.',
#   u'neither',
#   u'actor',
#   u'has',
#   u'any',
#   u'good',
#   u'words',
#   u'to',
#   u'work',
#   u'with',
#   u',',
#   u'and',
#   u'the',
#   u'lines',
#   u'simply',
#   u'aren',
#   u"'",
#   u't',
#   u'funny',
#   u',',
#   u'nor',
#   u'believable',
#   u'.',
#   u'perhaps',
#   u'the',
#   u'worst',
#   u'example',
#   u'of',
#   u'this',
#   u'is',
#   u'when',
#   u'the',
#   u'group',
#   u'of',
#   u'merry',
#   u'men',
#   u'encounter',
#   u'a',
#   u'man',
#   u'playing',
#   u'a',
#   u'macaulay',
#   u'culkin',
#   u'clone',
#   u'from',
#   u'the',
#   u'hit',
#   u'movie',
#   u'home',
#   u'alone',
#   u'.',
#   u'this',
#   u'particular',
#   u'scene',
#   u'is',
#   u'so',
#   u'out',
#   u'of',
#   u'place',
#   u'and',
#   u'so',
#   u'badly',
#   u'acted',
#   u',',
#   u'and',
#   u'followed',
#   u'by',
#   u'so',
#   u'many',
#   u'other',
#   u'scenes',
#   u'of',
#   u'equal',
#   u'miserable',
#   u'ideas',
#   u',',
#   u'that',
#   u'i',
#   u'really',
#   u'felt',
#   u'like',
#   u'leaving',
#   u'the',
#   u'theatre',
#   u'.',
#   u'much',
#   u'of',
#   u'the',
#   u'audience',
#   u'continued',
#   u'to',
#   u'look',
#   u'at',
#   u'their',
#   u'watches',
#   u'throughout',
#   u',',
#   u'and',
#   u'some',
#   u'left',
#   u'the',
#   u'theatre',
#   u'.',
#   u'chuckles',
#   u'were',
#   u'few',
#   u'and',
#   u'far',
#   u'between',
#   u',',
#   u'and',
#   u'they',
#   u'mostly',
#   u'dealt',
#   u'with',
#   u'visual',
#   u'jokes',
#   u'(',
#   u'such',
#   u'as',
#   u'an',
#   u'old',
#   u',',
#   u'beaten',
#   u'up',
#   u'horse',
#   u'from',
#   u'"',
#   u'rent',
#   u'-',
#   u'a',
#   u'-',
#   u'wreck',
#   u'"',
#   u')',
#   u'then',
#   u'from',
#   u'any',
#   u'dialogue',
#   u'whatsoever',
#   u'.',
#   u'scenes',
#   u'that',
#   u'could',
#   u'have',
#   u'been',
#   u'classics',
#   u',',
#   u'such',
#   u'as',
#   u'the',
#   u'archery',
#   u'contest',
#   u',',
#   u'are',
#   u'ruined',
#   u'by',
#   u'poor',
#   u'acting',
#   u'.',
#   u'perhaps',
#   u'the',
#   u'largest',
#   u'problem',
#   u'with',
#   u'the',
#   u'movie',
#   u'is',
#   u'that',
#   u'it',
#   u'is',
#   u'simply',
#   u'offensive',
#   u'.',
#   u'the',
#   u'basic',
#   u'plot',
#   u',',
#   u'that',
#   u'robin',
#   u'has',
#   u'received',
#   u'a',
#   u'key',
#   u'that',
#   u'will',
#   u'unlock',
#   u'the',
#   u'chastity',
#   u'belt',
#   u'of',
#   u'maid',
#   u'marian',
#   u',',
#   u'is',
#   u'not',
#   u'witty',
#   u'nor',
#   u'funny',
#   u'.',
#   u'mel',
#   u'brooks',
#   u'as',
#   u'a',
#   u'circumcision',
#   u'-',
#   u'giving',
#   u'rabbi',
#   u'is',
#   u'also',
#   u'offensive',
#   u'to',
#   u'me',
#   u'and',
#   u'others',
#   u'in',
#   u'the',
#   u'audience',
#   u'(',
#   u'not',
#   u'all',
#   u'jewish',
#   u',',
#   u'either',
#   u')',
#   u'.',
#   u'the',
#   u'movie',
#   u'simply',
#   u'tries',
#   u'to',
#   u'hard',
#   u'trying',
#   u'to',
#   u'be',
#   u'funny',
#   u'and',
#   u'by',
#   u'and',
#   u'large',
#   u'fails',
#   u'.',
#   u'the',
#   u'addition',
#   u'of',
#   u'a',
#   u'blind',
#   u'man',
#   u'who',
#   u'stumbles',
#   u'around',
#   u',',
#   u'falling',
#   u'off',
#   u'cliffs',
#   u',',
#   u'walking',
#   u'into',
#   u'ledges',
#   u'and',
#   u'being',
#   u'a',
#   u'general',
#   u'buffoon',
#   u'could',
#   u'have',
#   u'had',
#   u'some',
#   u'humorous',
#   u'potential',
#   u',',
#   u'but',
#   u'is',
#   u'also',
#   u'made',
#   u'terribly',
#   u'offensive',
#   u'.',
#   u'the',
#   u'only',
#   u'reason',
#   u'to',
#   u'see',
#   u'this',
#   u'movie',
#   u'is',
#   u'the',
#   u'surprise',
#   u'actor',
#   u'at',
#   u'the',
#   u'end',
#   u'who',
#   u'plays',
#   u'king',
#   u'richard',
#   u'.',
#   u'he',
#   u'is',
#   u'well',
#   u'worth',
#   u'waiting',
#   u'for',
#   u',',
#   u'if',
#   u'you',
#   u'can',
#   u'stand',
#   u'an',
#   u'hour',
#   u'and',
#   u'half',
#   u'of',
#   u'unfunny',
#   u'dialogue',
#   u',',
#   u'excruciating',
#   u'visual',
#   u'humor',
#   u',',
#   u'old',
#   u'puns',
#   u',',
#   u'ancient',
#   u'jokes',
#   u'and',
#   u'bad',
#   u'acting',
#   u'.',
#   u'if',
#   u'you',
#   u'can',
#   u"'",
#   u't',
#   u',',
#   u'don',
#   u"'",
#   u't',
#   u'even',
#   u'bother',
#   u'watching',
#   u'this',
#   u'miserable',
#   u'film',
#   u'.'],
#  u'neg')

# %%
len(documents)
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
# Out:
# <FreqDist with 39768 samples and 1583820 outcomes>

# %%
#print(all_words.items())

word_features = all_words.keys()[:2000]

print(word_features[4])
# Out:
# spiders

# %%
def document_features(document):
   ....:     document_words = set(document)
   ....:     features = {}
   ....:     for word in word_features:
   ....:         features['contains(%s)' % word] = (word in document_words)
   ....:     return features
   ....:

# %%
 print document_features(movie_reviews.words('pos/cv957_8737.txt'))
# Out:
# {u'contains(corporate)': False, u'contains(barred)': False, u'contains(batmans)': False, u'contains(menacing)': False, u'contains(rags)': False, u'contains(inquires)': False, u'contains(nosebleeding)': False, u'contains(playhouse)': False, u'contains(peculiarities)': False, u'contains(kilgore)': False, u'contains(tarnish)': False, u'contains(sand)': False, u'contains(busting)': False, u'contains(wedge)': False, u'contains(smelling)': False, u'contains(tulip)': False, u'contains(singled)': False, u'contains(wahlberg)': False, u'contains(needed)': False, u'contains(lydia)': False, u'contains(rick)': False, u'contains(cambodia)': False, u'contains(outfielders)': False, u'contains(jovivich)': False, u'contains(pinon)': False, u'contains(fix)': False, u'contains(marla)': False, u'contains(resources)': False, u'contains(nomi)': False, u'contains(irs)': False, u'contains(mason)': False, u'contains(vicariously)': False, u'contains(ingrained)': False, u'contains(skepticism)': False, u'contains(tested)': False, u'contains(spat)': False, u'contains(nfeatured)': False, u'contains(accomplishes)': False, u'contains(sierra)': False, u'contains(lunges)': False, u'contains(telefixated)': False, u'contains(wednesday)': False, u'contains(spiders)': False, u'contains(waft)': False, u'contains(jim)': False, u'contains(cinematic)': False, u'contains(pseudonymous)': False, u'contains(troubles)': False, u'contains(dimension)': False, u'contains(cassette)': False, u'contains(corsucant)': False, u'contains(absolute)': False, u'contains(harmonious)': False, u'contains(saying)': False, u'contains(misdemeanors)': False, u'contains(prodigious)': False, u'contains(reclining)': False, u'contains(loudness)': False, u'contains(lombard)': False, u'contains(sickening)': False, u'contains(cooking)': False, u'contains(oprah)': False, u'contains(platt)': False, u'contains(rolf)': False, u'contains(episodes)': False, u'contains(derivative)': False, u'contains(receipt)': False, u'contains(impactful)': False, u'contains(fonzie)': False, u'contains(chyron)': False, u'contains(dragonflies)': False, u'contains(ugliness)': False, u'contains(sauce)': False, u'contains(crossroads)': False, u'contains(paired)': False, u'contains(tomei)': False, u'contains(hounds)': False, u'contains(marshmallows)': False, u'contains(lick)': False, u'contains(hass)': False, u'contains(surges)': False, u'contains(watched)': False, u'contains(ivey)': False, u'contains(nuez)': False, u'contains(mentors)': False, u'contains(tricky)': False, u'contains(surveying)': False, u'contains(ditching)': False, u'contains(haystack)': False, u'contains(warriors)': False, u'contains(purged)': False, u'contains(rehabilitation)': False, u'contains(petitions)': False, u'contains(bogs)': False, u'contains(absense)': False, u'contains(courtesans)': False, u'contains(followed)': False, u'contains(har)': False, u'contains(anthesis)': False, u'contains(grotesqe)': False, u'contains(_i_know_what_you_did_last_summer_)': False, u'contains(survey)': False, u'contains(bartok)': False, u'contains(thivisol)': False, u'contains(exponential)': False, u'contains(birdie)': False, u'contains(cincinnati)': False, u'contains(unthrilling)': False, u'contains(balsan)': False, u'contains(bumming)': False, u'contains(celebrated)': False, u'contains(renovated)': False, u'contains(crowd)': False, u'contains(shows)': False, u'contains(lana)': False, u'contains(haskin)': False, u'contains(despite)': False, u'contains(scharzenegger)': False, u'contains(undergone)': False, u'contains(aissa)': False, u'contains(leit)': False, u'contains(mouth)': False, u'contains(demeaning)': False, u'contains(drilling)': False, u'contains(unsworth)': False, u'contains(bannister)': False, u'contains(wiseguy)': False, u'contains(lackies)': False, u'contains(norville)': False, u'contains(dampens)': False, u'contains(satisfactory)': False, u'contains(abuser)': False, u'contains(had)': False, u'contains(nature)': False, u'contains(awake)': False, u'contains(wise ...

# %%
featuresets = [(document_features(d), c) for (d, c) in documents]

# %%
print(featuresets[0])
# Out:
# ({u'contains(corporate)': False, u'contains(barred)': False, u'contains(batmans)': False, u'contains(menacing)': False, u'contains(rags)': False, u'contains(inquires)': False, u'contains(nosebleeding)': False, u'contains(playhouse)': False, u'contains(peculiarities)': False, u'contains(kilgore)': False, u'contains(tarnish)': False, u'contains(sand)': False, u'contains(busting)': False, u'contains(wedge)': False, u'contains(smelling)': False, u'contains(tulip)': False, u'contains(singled)': False, u'contains(wahlberg)': False, u'contains(needed)': False, u'contains(lydia)': False, u'contains(rick)': False, u'contains(cambodia)': False, u'contains(outfielders)': False, u'contains(jovivich)': False, u'contains(pinon)': False, u'contains(fix)': False, u'contains(marla)': False, u'contains(resources)': False, u'contains(nomi)': False, u'contains(irs)': False, u'contains(mason)': False, u'contains(vicariously)': False, u'contains(ingrained)': False, u'contains(skepticism)': False, u'contains(tested)': False, u'contains(spat)': False, u'contains(nfeatured)': False, u'contains(accomplishes)': False, u'contains(sierra)': False, u'contains(lunges)': False, u'contains(telefixated)': False, u'contains(wednesday)': False, u'contains(spiders)': False, u'contains(waft)': False, u'contains(jim)': False, u'contains(cinematic)': False, u'contains(pseudonymous)': False, u'contains(troubles)': False, u'contains(dimension)': False, u'contains(cassette)': False, u'contains(corsucant)': False, u'contains(absolute)': False, u'contains(harmonious)': False, u'contains(saying)': False, u'contains(misdemeanors)': False, u'contains(prodigious)': False, u'contains(reclining)': False, u'contains(loudness)': False, u'contains(lombard)': False, u'contains(sickening)': False, u'contains(cooking)': False, u'contains(oprah)': False, u'contains(platt)': False, u'contains(rolf)': False, u'contains(episodes)': False, u'contains(derivative)': False, u'contains(receipt)': False, u'contains(impactful)': False, u'contains(fonzie)': False, u'contains(chyron)': False, u'contains(dragonflies)': False, u'contains(ugliness)': False, u'contains(sauce)': False, u'contains(crossroads)': False, u'contains(paired)': False, u'contains(tomei)': False, u'contains(hounds)': False, u'contains(marshmallows)': False, u'contains(lick)': False, u'contains(hass)': False, u'contains(surges)': False, u'contains(watched)': False, u'contains(ivey)': False, u'contains(nuez)': False, u'contains(mentors)': False, u'contains(tricky)': False, u'contains(surveying)': False, u'contains(ditching)': False, u'contains(haystack)': False, u'contains(warriors)': False, u'contains(purged)': False, u'contains(rehabilitation)': False, u'contains(petitions)': False, u'contains(bogs)': False, u'contains(absense)': False, u'contains(courtesans)': False, u'contains(followed)': True, u'contains(har)': False, u'contains(anthesis)': False, u'contains(grotesqe)': False, u'contains(_i_know_what_you_did_last_summer_)': False, u'contains(survey)': False, u'contains(bartok)': False, u'contains(thivisol)': False, u'contains(exponential)': False, u'contains(birdie)': False, u'contains(cincinnati)': False, u'contains(unthrilling)': False, u'contains(balsan)': False, u'contains(bumming)': False, u'contains(celebrated)': False, u'contains(renovated)': False, u'contains(crowd)': False, u'contains(shows)': False, u'contains(lana)': False, u'contains(haskin)': False, u'contains(despite)': False, u'contains(scharzenegger)': False, u'contains(undergone)': False, u'contains(aissa)': False, u'contains(leit)': False, u'contains(mouth)': False, u'contains(demeaning)': False, u'contains(drilling)': False, u'contains(unsworth)': False, u'contains(bannister)': False, u'contains(wiseguy)': False, u'contains(lackies)': False, u'contains(norville)': False, u'contains(dampens)': False, u'contains(satisfactory)': False, u'contains(abuser)': False, u'contains(had)': True, u'contains(nature)': False, u'contains(awake)': False, u'contains(wiseg ...

# %%
train_set, test_set = featuresets[100:], featuresets[:100]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print nltk.classify.accuracy(classifier, test_set)
classifier.show_most_informative_features(10)
# Out:
# 0.71
# Most Informative Features
#     contains(mediocrity) = True              neg : pos    =      7.6 : 1.0
#           contains(sans) = True              neg : pos    =      7.6 : 1.0
#          contains(tripe) = True              neg : pos    =      7.6 : 1.0
#      contains(dismissed) = True              pos : neg    =      7.1 : 1.0
#    contains(overwhelmed) = True              pos : neg    =      6.4 : 1.0
#         contains(fabric) = True              pos : neg    =      6.4 : 1.0
#    contains(bruckheimer) = True              neg : pos    =      6.3 : 1.0
#          contains(wires) = True              neg : pos    =      6.3 : 1.0
#      contains(uplifting) = True              pos : neg    =      6.2 : 1.0
#         contains(doubts) = True              pos : neg    =      5.9 : 1.0

# %%
classifier.classify( {u'contains(uplifting)': True})
# Out:
# u'pos'

# %%
from nltk.classify import MaxentClassifier
classifier = nltk.MaxentClassifier.train(train_set)
print nltk.classify.accuracy(classifier, test_set)
classifier.show_most_informative_features(10)
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -0.69315        0.497
# /home/ubuntu/githubrepo/NLTP/NLTP_Practice/venv/myenv/local/lib/python2.7/site-packages/nltk/classify/maxent.py:1313: RuntimeWarning: overflow encountered in power
#   exp_nf_delta = 2 ** nf_delta
# /home/ubuntu/githubrepo/NLTP/NLTP_Practice/venv/myenv/local/lib/python2.7/site-packages/nltk/classify/maxent.py:1315: RuntimeWarning: invalid value encountered in multiply
#   sum1 = numpy.sum(exp_nf_delta * A, axis=0)
# /home/ubuntu/githubrepo/NLTP/NLTP_Practice/venv/myenv/local/lib/python2.7/site-packages/nltk/classify/maxent.py:1316: RuntimeWarning: invalid value encountered in multiply
#   sum2 = numpy.sum(nf_exp_nf_delta * A, axis=0)
# /home/ubuntu/githubrepo/NLTP/NLTP_Practice/venv/myenv/local/lib/python2.7/site-packages/nltk/classify/maxent.py:1323: RuntimeWarning: invalid value encountered in divide
#   deltas -= (ffreq_empirical - sum1) / -sum2
#          Final               nan        0.503
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-3fca6dd8478e> in <module>()
#       1 from nltk.classify import MaxentClassifier
#       2 classifier = nltk.MaxentClassifier.train(train_set)
# ----> 3 print nltk.classify.accuracy(classifier, test_set)
#       4 classifier.show_most_informative_features(10)
#
# /home/ubuntu/githubrepo/NLTP/NLTP_Practice/venv/myenv/local/lib/python2.7/site-packages/nltk/classify/util.pyc in accuracy(classifier, gold)
#      85
#      86 def accuracy(classifier, gold):
# ---> 87     results = classifier.classify_many([fs for (fs, l) in gold])
#      88     correct = [l == r for ((fs, l), r) in zip(gold, results)]
#      89     if correct:
#
# ValueError: too many values to unpack

# %%
test_text = "I love this movie, very interesting"
test_set = document_features(test_text.split())
test_set
print classifier.classify(test_set)
print maxent_classifier.classify(test_set)
# Out:
# neg
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-d917befdacb1> in <module>()
#       3 test_set
#       4 print classifier.classify(test_set)
# ----> 5 print maxent_classifier.classify(test_set)
#
# NameError: name 'maxent_classifier' is not defined
